# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans
import os
os.environ['OMP_NUM_THREADS'] = '1'

# %%
data=pd.read_csv("datasets/ex.csv")
data
# Out:
#     V1   V2
# 0  1.0  1.0
# 1  1.5  2.0
# 2  3.0  4.0
# 3  5.0  7.0
# 4  3.5  5.0
# 5  4.5  5.0
# 6  3.5  4.5

# %%
f1=data['V1'].values
f2=data['V2'].values

# %%
X=np.array(list(zip(f1,f2)))
print("X: ",X)
# Out:
# X:  [[1.  1. ]
#  [1.5 2. ]
#  [3.  4. ]
#  [5.  7. ]
#  [3.5 5. ]
#  [4.5 5. ]
#  [3.5 4.5]]

# %%
plt.title("Graph for whole datasets: ")
plt.scatter(f1,f2,c='black')
plt.show()

# %%
kmeans=KMeans(n_clusters=2,n_init=10)
labels=kmeans.fit(X).predict(X)
print("Labels for K-Means: ", labels)
# Out:
# C:\Users\Abhishek\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Labels for K-Means:  [1 1 0 0 0 0 0]

# %%
plt.title("Graph for K Means algorithm:")
plt.scatter(f1,f2,c=labels)
centroids=kmeans.cluster_centers_
print("Centroids: ",centroids)
plt.scatter(centroids[:,0],centroids[:,1],marker='*',c='red')
plt.show()
# Out:
# Centroids:  [[3.9  5.1 ]
#  [1.25 1.5 ]]

# %%
#Expectation and Maximization-EM
gmm=GaussianMixture(2)
labels=gmm.fit(X).predict(X)
print("Labels for GMM: ",labels)
# Out:
# Labels for GMM:  [1 1 0 0 0 0 0]
# C:\Users\Abhishek\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
plt.title("Graph using GMM algorithm")
plt.scatter(f1,f2,c=labels)
plt.show()
